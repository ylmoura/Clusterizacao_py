# %% [markdown]
# # 0.0 Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt
from IPython.display import HTML

from yellowbrick.cluster import KElbowVisualizer  ## pip install yellowbrick


from sklearn import cluster as c

# %% [markdown]
# ## 0.1. Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'ggplot')
    plt.rcParams['figure.figsize'] = [24, 9]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2 Load dataset

# %%
# load 

df_raw = pd.read_csv('../data/raw/Ecommerce.csv', encoding='unicode_escape', low_memory= False)

df_raw = df_raw.drop( columns= ['Unnamed: 8'], axis = 1)
df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   29-Nov-16       2.55     17850.0  United Kingdom
# 1    536365     71053                  WHITE METAL LANTERN         6   29-Nov-16       3.39     17850.0  United Kingdom
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8   29-Nov-16       2.75     17850.0  United Kingdom
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   29-Nov-16       3.39     17850.0  United Kingdom
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6   29-Nov-16       3.39     17850.0  United Kingdom

# %% [markdown]
# # <font color='red'> 1.0. Descrição dos dados </font>

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1. Rename columns

# %%
df1.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
cols_new = ['invoice_no', 'stock_code', 'description','quantity', 'invoice_date', 'unit_price', 'customer_id', 'country']
df1.columns = cols_new

# %% [markdown]
# ## 1.2. Data dimensions

# %%
print( 'Number of rows: {}'.format (df1.shape[0]))
print( 'Number of columns: {}'.format (df1.shape[1]))
# Out:
# Number of rows: 541909
# Number of columns: 8

# %% [markdown]
# ## 1.3. Data types

# %%
df1.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %% [markdown]
# ## 1.5. Replace NA

# %%
# Remova na
df1 = df1.dropna (subset=['description', 'customer_id'])



print('Removed data: {:.2f}%'.format(1-(df1.shape[0] / df_raw.shape[0])))
# Out:
# Removed data: 0.25%

# %% [markdown]
# ## 1.6. Change dtypes

# %%
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6    29-Nov-16        2.55      17850.0  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6    29-Nov-16        3.39      17850.0  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8    29-Nov-16        2.75      17850.0  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6    29-Nov-16        3.39      17850.0  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6    29-Nov-16        3.39      17850.0  United Kingdom

# %%
# invoice_date
df1['invoice_date'] = pd.to_datetime (df1['invoice_date'], format='%d-%b-%y')

# customer_id

df1['customer_id'] = df1['customer_id'].astype ( int )
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   2016-11-29        2.55        17850  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6   2016-11-29        3.39        17850  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8   2016-11-29        2.75        17850  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   2016-11-29        3.39        17850  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6   2016-11-29        3.39        17850  United Kingdom

# %% [markdown]
# ## 1.7 Descriptive Statistics

# %% [markdown]
# # <font color='red'> 2.0. Feature Engineering </font>

# %%
df2= df1.copy()

# %% [markdown]
# ## 2.1. Feature Creation

# %%
df2.head()
# Out:
#   invoice_no stock_code                          description  quantity invoice_date  unit_price  customer_id         country
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6   2016-11-29        2.55        17850  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN         6   2016-11-29        3.39        17850  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8   2016-11-29        2.75        17850  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6   2016-11-29        3.39        17850  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6   2016-11-29        3.39        17850  United Kingdom

# %%
# data reference > trabalhando com id e data unico

df_ref = df2.drop(['invoice_no', 'stock_code', 'description','quantity', 'invoice_date','unit_price', 'country'], axis = 1).drop_duplicates(ignore_index=True)

# %%
# Cross Revenue ( Faturamento ) quantity * price = Faturamento
df2['gross_revenue'] = df2['quantity'] * df2['unit_price']

# Monetary
df_monetary =  df2[['customer_id', 'gross_revenue']].groupby( 'customer_id').sum().reset_index()
df_ref = pd.merge ( df_ref, df_monetary, on= 'customer_id', how='left')


# Recency - Last dat purchase
df_recency = df2[['customer_id', 'invoice_date']].groupby('customer_id').max().reset_index()
df_recency['recency_days'] = (df2['invoice_date'].max() - df_recency['invoice_date']).dt.days  # ao invés de utilizar apply estou utilizando dt para transformar em inteiro
df_recency = df_recency[['customer_id','recency_days']].copy() # fiz isso para escolher quais coluna entra no join
df_ref = pd.merge ( df_ref, df_recency, on= 'customer_id', how='left')

# Frequency
df_freq = df2[['customer_id','invoice_no']].drop_duplicates().groupby('customer_id').count().reset_index()
df_ref = pd.merge ( df_ref, df_freq, on= 'customer_id', how='left')
df_ref.head()
# Out:
#    customer_id  gross_revenue  recency_days  invoice_no
# 0        17850        5288.63           302          35
# 1        13047        3079.10            31          18
# 2        12583        7187.34             2          18
# 3        13748         948.25            95           5
# 4        15100         635.10           330           6

# %% [markdown]
# # <font color='red'> 3.0. Filtragem de Variaveis </font>

# %%
df3 = df_ref.copy()

# %% [markdown]
# # <font color='red'> 4.0. EDA </font>

# %%
df4 = df3.copy()

# %% [markdown]
# # <font color='red'> 5.0. Data Preparation </font>

# %%
df5 = df4.copy()

# %% [markdown]
# # <font color='red'> 6.0. Feature Selection </font>

# %%
df6 = df5.copy()

# %% [markdown]
# # <font color='red'> 7.0. Hyperparameter Fine-Tunning</font>

# %%
X = df6.drop( columns=['customer_id'])

# %%
clusters = [2,3,4,5,6]

# %% [markdown]
# ## 7.1. Within-Clusteer Sum of Square (WSS)

# %%
wss = []
for k in clusters:
    # model definition  
    kmeans = c.KMeans( init='random', n_clusters=k, n_init=10, max_iter=300 )
    # model training 
    kmeans.fit( X )
    # validation 
    wss.append(kmeans.inertia_)
    
# plot wss - ELBOW METHOD 
# tenho que escolher o lugar que o ponto mais se desloca e testar para saber o cluster para utilizar nesse exemplo foi 3 e 5
plt.plot (clusters, wss,linestyle='--', marker='o', color='b')
plt.xlabel ( 'K');
plt.ylabel ( 'Within-Cluster Sum of Square')
plt.title( 'WSS VS k');
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/366 [00:00<?, ?it/s]
# Examining munkres:   0%|          | 0/366 [00:00<?, ?it/s]
# Examining bleach:   0%|          | 1/366 [00:00<00:14, 24.39it/s]
# Examining lazy-object-proxy:   1%|          | 2/366 [00:00<02:36,  2.32it/s]
# Examining lazy-object-proxy:   1%|          | 3/366 [00:00<01:44,  3.48it/s]
# Examining m2w64-gcc-libs-core:   1%|          | 3/366 [00:00<01:44,  3.48it/s]
# Examining m2w64-gcc-libs-core:   1%|1         | 4/366 [00:00<01:22,  4.37it/s]
# Examining msys2-conda-epoch:   1%|1         | 4/366 [00:00<01:22,  4.37it/s]
# Examining sphinxcontrib:   1%|1         | 5/366 [00:00<01:22,  4.37it/s]
# Examining unidecode:   2%|1         | 6/366 [00:00<01:22,  4.37it/s]
# Examining distributed:   2%|1         | 7/366 [00:01<01:22,  4.37it/s]
# Examining qtconsole:   2%|2         | 8/366 [00:11<01:21,  4.37it/s]
# Examining qtconsole:   2%|2         | 9/366 [00:11<09:31,  1.60s/it]
# Examining cryptography:   2%|2         | 9/366 [00:14<09:31,  1.60s/it]
# Examining cryptography:   3%|2         | 10/366 [00:14<10:06,  1.70s/it]
# Examining path.py:   3%|2         | 10/366 [00:15<10:06,  1.70s/it]
# Examining path.py:   3%|3         | 11/366 [00:15<09:58,  1.68s/it]
# Examining icc_rt:   3%|3         | 11/366 [00:15<09:58,  1.68s/it]
# Examining icc_rt:   3%|3         | 12/366 [00:15<07:58,  1.35s/it]
# Examining sphinx:   3%|3         | 12/366 [00:15<07:58,  1.35s/it]
# Examining libxml2:   4%|3         | 13/366 [00:18<07:57,  1.35s/it]
# Examining libxml2:   4%|3         | 14/366 [00:18<08:14,  1.41s/it]
# Examining anyio:   4%|3         | 14/366 [00:18<08:14,  1.41s/it]
# Examining blosc:   4%|4         | 15/366 [00:19<08:13,  1.41s/it]
# Examining blosc:   4%|4         | 16/366 [00:19<05:26,  1.07it/s]
# Examining pywavelets:   4%|4         | 16/366 [00:19<05:26,  1.07it/s]
# Examining xlwings:   5%|4         | 17/366 [00:20<05:25,  1.07it/s]
# Examining xlwings:   5%|4         | 18/366 [00:20<05:10,  1.12it/s]
# Examining toml:   5%|4         | 18/366 [00:21<05:10,  1.12it/s]
# Examining toml:   5%|5         | 19/366 [00:21<05:06,  1.13it/s]
# Examining krb5:   5%|5         | 19/366 [00:21<05:06,  1.13it/s]
# Examining async_generator:   5%|5         | 20/366 [00:21<05:05,  1.13it/s]
# Examining async_generator:   6%|5         | 21/366 [00:21<03:23,  1.69it/s]
# Examining libaec:   6%|5         | 21/366 [00:21<03:23,  1.69it/s]
# Examining cfitsio:   6%|6         | 22/366 [00:21<03:23,  1.69it/s]
# Examining snowballstemmer:   6%|6         | 23/366 [00:21<03:22,  1.69it/s]
# Examining keyring:   7%|6         | 24/366 [00:21<03:21,  1.69it/s]
# Examining keyring:   7%|6         | 25/366 [00:21<01:45,  3.23it/s]
# Examining debugpy:   7%|6         | 25/366 [00:22<01:45,  3.23it/s]
# Examining networkx:   7%|7         | 26/366 [00:22<01:45,  3.23it/s]
# Examining networkx:   7%|7         | 27/366 [00:22<01:43,  3.27it/s]
# Examining urllib3:   7%|7         | 27/366 [00:22<01:43,  3.27it/s]
# Examining scikit-image:   8%|7         | 28/366 [00:24<01:43,  3.27it/s]
# Examining scikit-image:   8%|7         | 29/366 [00:24<03:13,  1.74it/s]
# Examining imageio:   8%|7         | 29/366 [00:30<03:13,  1.74it/s]
# Examining imageio:   8%|8         | 30/366 [00:30<07:55,  1.41s/it]
# Examining xz:   8%|8         | 30/366 [00:32<07:55,  1.41s/it]
# Examining xz:   8%|8         | 31/366 [00:32<08:36,  1.54s/it]
# Examining sortedcontainers:   8%|8         | 31/366 [00:32<08:36,  1.54s/it]
# Examining m2w64-gcc-libgfortran:   9%|8         | 32/366 [00:32<08:34,  1.54s/it]
# Examining libspatialindex:   9%|9         | 33/366 [00:32<08:33,  1.54s/it]
# Examining libiconv:   9%|9         | 34/366 [00:32<08:31,  1.54s/it]
# Examining pysocks:  10%|9         | 35/366 [00:32<08:30,  1.54s/it]
# Examining tornado:  10%|9         | 36/366 [00:32<08:28,  1.54s/it]
# Examining tornado:  10%|#         | 37/366 [00:32<03:18,  1.66it/s]
# Examining dataclasses:  10%|#         | 37/366 [00:32<03:18,  1.66it/s]
# Examining clyent:  10%|#         | 38/366 [00:33<03:17,  1.66it/s]
# Examining clyent:  11%|#         | 39/366 [00:33<02:38,  2.06it/s]
# Examining python-libarchive-c:  11%|#         | 39/366 [00:33<02:38,  2.06it/s]
# Examining tqdm:  11%|#         | 40/366 [00:33<02:38,  2.06it/s]
# Examining tqdm:  11%|#1        | 41/366 [00:33<02:21,  2.30it/s]
# Examining pyreadline:  11%|#1        | 41/366 [00:34<02:21,  2.30it/s]
# Examining xlsxwriter:  11%|#1        | 42/366 [00:34<02:21,  2.30it/s]
# Examining xlsxwriter:  12%|#1        | 43/366 [00:34<02:13,  2.42it/s]
# Examining tk:  12%|#1        | 43/366 [00:34<02:13,  2.42it/s]
# Examining tk:  12%|#2        | 44/366 [00:34<02:12,  2.42it/s]
# Examining intel-openmp:  12%|#2        | 44/366 [00:34<02:12,  2.42it/s]
# Examining pkginfo:  12%|#2        | 45/366 [00:34<02:12,  2.42it/s]
# Examining bcrypt:  13%|#2        | 46/366 [00:34<02:11,  2.42it/s]
# Examining bcrypt:  13%|#2        | 47/366 [00:34<01:23,  3.83it/s]
# Examining bitarray:  13%|#2        | 47/366 [00:35<01:23,  3.83it/s]
# Examining tblib:  13%|#3        | 48/366 [00:35<01:23,  3.83it/s]
# Examining tblib:  13%|#3        | 49/366 [00:35<01:38,  3.23it/s]
# Examining conda-content-trust:  13%|#3        | 49/366 [00:35<01:38,  3.23it/s]
# Examining pytest:  14%|#3        | 50/366 [00:35<01:37,  3.23it/s]
# Examining pytest:  14%|#3        | 51/366 [00:35<01:20,  3.93it/s]
# Examining soupsieve:  14%|#3        | 51/366 [00:40<01:20,  3.93it/s]
# Examining soupsieve:  14%|#4        | 52/366 [00:40<05:27,  1.04s/it]
# Examining rope:  14%|#4        | 52/366 [00:40<05:27,  1.04s/it]
# Examining rope:  14%|#4        | 53/366 [00:40<04:31,  1.15it/s]
# Examining et_xmlfile:  14%|#4        | 53/366 [00:41<04:31,  1.15it/s]
# Examining et_xmlfile:  15%|#4        | 54/366 [00:41<03:43,  1.39it/s]
# Examining numpydoc:  15%|#4        | 54/366 [00:41<03:43,  1.39it/s]
# Examining jpeg:  15%|#5        | 55/366 [00:41<03:43,  1.39it/s]
# Examining jpeg:  15%|#5        | 56/366 [00:41<02:59,  1.72it/s]
# Examining prometheus_client:  15%|#5        | 56/366 [00:41<02:59,  1.72it/s]
# Examining tbb:  16%|#5        | 57/366 [00:42<02:59,  1.72it/s]
# Examining tbb:  16%|#5        | 58/366 [00:42<02:21,  2.18it/s]
# Examining vc:  16%|#5        | 58/366 [00:42<02:21,  2.18it/s]
# Examining filelock:  16%|#6        | 59/366 [00:42<02:21,  2.18it/s]
# Examining entrypoints:  16%|#6        | 60/366 [00:42<02:20,  2.18it/s]
# Examining entrypoints:  17%|#6        | 61/366 [00:42<01:25,  3.58it/s]
# Examining mock:  17%|#6        | 61/366 [00:42<01:25,  3.58it/s]
# Examining chardet:  17%|#6        | 62/366 [00:42<01:24,  3.58it/s]
# Examining chardet:  17%|#7        | 63/366 [00:42<01:05,  4.63it/s]
# Examining text-unidecode:  17%|#7        | 63/366 [00:42<01:05,  4.63it/s]
# Examining typing_extensions:  17%|#7        | 64/366 [00:42<01:05,  4.63it/s]
# Examining typing_extensions:  18%|#7        | 65/366 [00:42<00:55,  5.39it/s]
# Examining win_inet_pton:  18%|#7        | 65/366 [00:42<00:55,  5.39it/s]
# Examining conda-env:  18%|#8        | 66/366 [00:42<00:55,  5.39it/s]
# Examining conda-env:  18%|#8        | 67/366 [00:42<00:46,  6.38it/s]
# Examining greenlet:  18%|#8        | 67/366 [00:42<00:46,  6.38it/s]
# Examining charset-normalizer:  19%|#8        | 68/366 [00:43<00:46,  6.38it/s]
# Examining charset-normalizer:  19%|#8        | 69/366 [00:43<00:38,  7.63it/s]
# Examining nbclient:  19%|#8        | 69/366 [00:43<00:38,  7.63it/s]
# Examining joblib:  19%|#9        | 70/366 [00:43<00:38,  7.63it/s]
# Examining joblib:  19%|#9        | 71/366 [00:43<00:36,  8.15it/s]
# Examining mkl_fft:  19%|#9        | 71/366 [00:43<00:36,  8.15it/s]
# Examining backcall:  20%|#9        | 72/366 [00:46<00:36,  8.15it/s]
# Examining backcall:  20%|#9        | 73/366 [00:46<02:44,  1.78it/s]
# Examining astroid:  20%|#9        | 73/366 [00:46<02:44,  1.78it/s]
# Examining nbconvert:  20%|##        | 74/366 [00:49<02:44,  1.78it/s]
# Examining nbconvert:  20%|##        | 75/366 [00:49<03:57,  1.23it/s]
# Examining pycparser:  20%|##        | 75/366 [00:50<03:57,  1.23it/s]
# Examining pycparser:  21%|##        | 76/366 [00:50<04:36,  1.05it/s]
# Examining brotli:  21%|##        | 76/366 [00:51<04:36,  1.05it/s]
# Examining brotli:  21%|##1       | 77/366 [00:51<03:46,  1.28it/s]
# Examining zfp:  21%|##1       | 77/366 [00:51<03:46,  1.28it/s]
# Examining terminado:  21%|##1       | 78/366 [00:51<03:45,  1.28it/s]
# Examining m2w64-libwinpthread-git:  22%|##1       | 79/366 [00:51<03:45,  1.28it/s]
# Examining m2w64-libwinpthread-git:  22%|##1       | 80/366 [00:51<02:15,  2.10it/s]
# Examining pip:  22%|##1       | 80/366 [00:51<02:15,  2.10it/s]
# Examining get_terminal_size:  22%|##2       | 81/366 [00:54<02:15,  2.10it/s]
# Examining get_terminal_size:  22%|##2       | 82/366 [00:54<03:37,  1.30it/s]
# Examining sympy:  22%|##2       | 82/366 [00:54<03:37,  1.30it/s]
# Examining jedi:  23%|##2       | 83/366 [00:54<03:37,  1.30it/s]
# Examining jedi:  23%|##2       | 84/366 [00:54<02:48,  1.67it/s]
# Examining dal:  23%|##2       | 84/366 [00:54<02:48,  1.67it/s]
# Examining dal:  23%|##3       | 85/366 [00:54<02:28,  1.89it/s]
# Examining olefile:  23%|##3       | 85/366 [00:54<02:28,  1.89it/s]
# Examining lerc:  23%|##3       | 86/366 [00:54<02:28,  1.89it/s]
# Examining win_unicode_console:  24%|##3       | 87/366 [00:54<02:27,  1.89it/s]
# Examining pandocfilters:  95%|#########5| 349/366 [05:32<00:06,  2.60it/s]
# Examining partd:  96%|#########5| 350/366 [05:32<00:06,  2.60it/s]
# Examining partd:  96%|#########5| 351/366 [05:32<00:04,  3.66it/s]
# Examining libtiff:  96%|#########5| 351/366 [05:32<00:04,  3.66it/s]
# Examining libtiff:  96%|#########6| 352/366 [05:32<00:03,  4.00it/s]
# Examining wcwidth:  96%|#########6| 352/366 [05:32<00:03,  4.00it/s]
# Examining libwebp:  96%|#########6| 353/366 [05:32<00:03,  4.00it/s]
# Examining libwebp:  97%|#########6| 354/366 [05:32<00:02,  5.42it/s]
# Examining intervaltree:  97%|#########6| 354/366 [05:32<00:02,  5.42it/s]
# Examining idna:  97%|#########6| 355/366 [05:32<00:02,  5.42it/s]
# Examining python=3.9:  97%|#########7| 356/366 [05:33<00:01,  5.42it/s]
# Examining python=3.9:  98%|#########7| 357/366 [05:33<00:01,  7.15it/s]
# Examining defusedxml:  98%|#########7| 357/366 [05:33<00:01,  7.15it/s]
# Examining requests:  98%|#########7| 358/366 [05:33<00:01,  7.15it/s]
# Examining requests:  98%|#########8| 359/366 [05:33<00:01,  6.78it/s]
# Examining locket:  98%|#########8| 359/366 [05:34<00:01,  6.78it/s]
# Examining locket:  98%|#########8| 360/366 [05:34<00:01,  4.08it/s]
# Examining giflib:  98%|#########8| 360/366 [05:34<00:01,  4.08it/s]
# Examining winpty:  99%|#########8| 361/366 [05:34<00:01,  4.08it/s]
# Examining kiwisolver:  99%|#########8| 362/366 [05:34<00:00,  4.08it/s]
# Examining isort:  99%|#########9| 363/366 [05:34<00:00,  4.08it/s]
# Examining isort:  99%|#########9| 364/366 [05:34<00:00,  6.92it/s]
# Examining lzo:  99%|#########9| 364/366 [05:35<00:00,  6.92it/s]
# Examining freetype: 100%|#########9| 365/366 [05:35<00:00,  6.92it/s]
# Examining freetype: 100%|##########| 366/366 [05:35<00:00,  3.19it/s]
#
#
# Determining conflicts:   0%|          | 0/366 [00:00<?, ?it/s]
# Examining conflict for matplotlib-base fonttools munkres anaconda:   0%|          | 0/366 [00:00<?, ?it/s]
# Examining conflict for munkres bleach lazy-object-proxy sphinxcontrib unidecode distributed qtconsole cryptography path.py sphinx anyio pywavelets xlwings toml krb5 async_generator snowballstemmer keyring debugpy networkx urllib3 scikit-image imageio sortedcontainers pysocks tornado dataclasses clyent python-libarchive-c tqdm pyreadline xlsxwriter pkginfo bcrypt bitarray tblib conda-content-trust pytest soupsieve rope et_xmlfile numpydoc prometheus_client filelock entrypoints mock chardet text-unidecode typing_extensions win_inet_pton greenlet charset-normalizer nbclient joblib mkl_fft backcall astroid nbconvert pycparser terminado pip sympy jedi olefile win_unicode_console werkzeug spyder ipython colorama h5py tbb4py zipp jinja2 backports.tempfile python-slugify jupyterlab_pygments xlwt future babel py-lief tinycss anaconda-project wrapt typed-ast pyrsistent nest-asyncio cached-property pycurl pyparsing ruamel_yaml pluggy llvmlite bokeh glob2 notebook sniffio three-merge console_shortcut numexpr simplegeneric matplotlib-base jupyterlab pexpect jupyterlab_widgets iniconfig argon2-cffi jupyter_console spyder-kernels conda pyls-spyder jupyter_server numba menuinst whichcraft multipledispatch itsdangerous poyo mistune _ipyw_jlab_nb_ext_conf atomicwrites json5 conda-verify jupyter_core pycosat contextlib2 pillow ipywidgets pyerfa openssl regex pyyaml backports.functools_lru_cache msgpack-python pathspec dask-core psutil cytoolz six navigator-updater cookiecutter numpy importlib-metadata sortedcollections fastcache pygments pyopenssl wheel arrow ptyprocess zope unicodecsv backports black setuptools bottleneck fsspec qstylizer parso matplotlib-inline pyqt sqlalchemy pep8 nbformat libcurl importlib_metadata pywin32 pylint matplotlib sphinxcontrib-qthelp watchdog pyflakes traitlets ujson statsmodels zict python-dateutil ipython_genutils daal4py docutils inflection nbclassic conda-pack yellowbrick flake8 jupyterlab_server libarchive patsy yapf conda-token attrs diff-match-patch mkl-service curl rtree tifffile prompt-toolkit jinja2-time backports.weakref autopep8 pycodestyle textdistance bkcharts anaconda pyzmq widgetsnbextension fonttools backports.shutil_get_terminal_size jsonschema path lxml sphinxcontrib-applehelp pydocstyle powershell_shortcut astropy pyjwt sip cloudpickle pandas decorator comtypes appdirs ipykernel prompt_toolkit imagesize binaryornot qtawesome sphinxcontrib-serializinghtml boto scipy sphinxcontrib-websupport pytables flask brotlipy pywin32-ctypes scikit-learn testpath pynacl ply anaconda-client conda-build qtpy pickleshare conda-repo-cli seaborn mpmath scikit-learn-intelex qt pathlib2 markupsafe jdcal anaconda-navigator python-lsp-black python-lsp-server numpy-base libssh2 send2trash webencodings toolz paramiko packaging nose asn1crypto cffi mkl_random dask qdarkstyle alabaster zope.event sphinxcontrib-htmlhelp jupyter_client threadpoolctl pywinpty sphinxcontrib-devhelp beautifulsoup4 imagecodecs nltk cython mypy_extensions openpyxl python-lsp-jsonrpc jupyter html5lib more-itertools pytz sphinxcontrib-jsmath xlrd argh singledispatch py cycler mccabe certifi conda-package-handling gevent wincertstore xmltodict click pyodbc zope.interface heapdict pandocfilters partd wcwidth intervaltree idna python defusedxml requests locket kiwisolver isort:   0%|          | 1/366 [00:14<1:25:12, 14.01s/it]
# ...
# python-lsp-server -> pylint[version='>=2.5.0'] -> platformdirs[version='>=2.2.0']
# black -> platformdirs[version='>=2']
#
# Package libarchive conflicts for:
# anaconda==2021.11 -> libarchive==3.4.2=h5e25573_0
# conda[version='>=4.12.0'] -> conda-package-handling[version='>=1.3.0'] -> libarchive[version='>=3.3.3']
# anaconda==2021.11 -> python-libarchive-c==2.9=pyhd3eb1b0_1 -> libarchive
# conda-verify -> conda-package-handling[version='>=1.0.4'] -> libarchive[version='>=3.3.3']
# conda-build -> conda-package-handling[version='>=1.3'] -> libarchive[version='>=3.3.3']
# python-libarchive-c -> libarchive
# conda-build -> libarchive
# conda-package-handling -> python-libarchive-c -> libarchive
# conda-package-handling -> libarchive[version='>=3.3.3']
#
# Package textdistance conflicts for:
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> textdistance[version='>=4.2.0']
# anaconda==2021.11 -> textdistance==4.2.1=pyhd3eb1b0_0
# spyder -> textdistance[version='>=4.2.0']
#
# Package unicodedata2 conflicts for:
# fonttools -> unicodedata2[version='>=13.0.0']
# matplotlib-base -> fonttools[version='>=4.22.0'] -> unicodedata2[version='>=13.0.0']
#
# Package mock conflicts for:
# pytables -> mock
# anaconda==2021.11 -> pytables==3.6.1=py39h56d22b6_1 -> mock
# anaconda==2021.11 -> mock==4.0.3=pyhd3eb1b0_0
#
# Package networkx conflicts for:
# anaconda==2021.11 -> scikit-image==0.18.3=py39hf11a4ad_0 -> networkx[version='>=2.0']
# anaconda==2021.11 -> networkx==2.6.3=pyhd3eb1b0_0
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0|>=2.2|>=2.2,<2.7']
#
# Package rope conflicts for:
# python-lsp-server -> rope[version='>=0.10.5']
# anaconda==2021.11 -> python-lsp-server==1.2.4=pyhd3eb1b0_0 -> rope[version='>=0.10.5']
# python-lsp-black -> python-lsp-server[version='>=1.4.0'] -> rope[version='>=0.10.5']
# anaconda==2021.11 -> rope==0.19.0=pyhd3eb1b0_0
# spyder -> rope[version='>=0.10.5|>=0.9.4']
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> rope[version='>=0.10.5']
#
# Package unidecode conflicts for:
# python-slugify -> unidecode[version='>=0.04.16|>=1.1.1']
# cookiecutter -> python-slugify[version='>=4.0.0'] -> unidecode[version='>=1.1.1']
# anaconda==2021.11 -> python-slugify==5.0.2=pyhd3eb1b0_0 -> unidecode[version='>=1.1.1']
# anaconda==2021.11 -> unidecode==1.2.0=pyhd3eb1b0_0
#
# Package poyo conflicts for:
# spyder -> cookiecutter[version='>=1.6.0'] -> poyo[version='>=0.5.0']
# anaconda==2021.11 -> cookiecutter==1.7.2=pyhd3eb1b0_0 -> poyo[version='>=0.5.0']
# cookiecutter -> poyo[version='>=0.5.0']
# anaconda==2021.11 -> poyo==0.5.0=pyhd3eb1b0_0
#
# Package py conflicts for:
# anaconda==2021.11 -> py==1.10.0=pyhd3eb1b0_0
# anaconda==2021.11 -> pytest==6.2.4=py39haa95532_2 -> py[version='>=1.8.2']
# pytest -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
# astropy -> pytest[version='<4'] -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
# yellowbrick -> pytest[version='>=5.0.0'] -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
#
# Package msys2-conda-epoch conflicts for:
# anaconda==2021.11 -> m2w64-gcc-libgfortran==5.3.0=6 -> msys2-conda-epoch[version='>=20160418']
# m2w64-libwinpthread-git -> msys2-conda-epoch[version='>=20160418']
# pywinpty -> m2w64-gcc-libs -> msys2-conda-epoch[version='>=20160418']
# m2w64-gmp -> msys2-conda-epoch[version='>=20160418']
# m2w64-gcc-libs -> msys2-conda-epoch[version='>=20160418']
# m2w64-gcc-libs-core -> msys2-conda-epoch[version='>=20160418']
# m2w64-gcc-libgfortran -> msys2-conda-epoch[version='>=20160418']
# conda-build -> m2-patch[version='>=2.6'] -> msys2-conda-epoch[version='>=20160418']
# anaconda==2021.11 -> msys2-conda-epoch==20160418=1
#
# Package jinja2-time conflicts for:
# anaconda==2021.11 -> jinja2-time==0.2.0=pyhd3eb1b0_2
# anaconda==2021.11 -> cookiecutter==1.7.2=pyhd3eb1b0_0 -> jinja2-time[version='>=0.2.0']
# cookiecutter -> jinja2-time[version='>=0.2.0']
# spyder -> cookiecutter[version='>=1.6.0'] -> jinja2-time[version='>=0.2.0']
#
# Package sphinxcontrib conflicts for:
# sphinx -> sphinxcontrib-websupport -> sphinxcontrib
# anaconda==2021.11 -> sphinxcontrib-websupport==1.2.4=py_0 -> sphinxcontrib
# anaconda==2021.11 -> sphinxcontrib==1.0[build='py38_1|py37_1|py39haa95532_1']
# sphinxcontrib-websupport -> sphinxcontrib
#
# Package filelock conflicts for:
# conda-build -> filelock
# anaconda==2021.11 -> filelock==3.3.1=pyhd3eb1b0_1
#
# Package comtypes conflicts for:
# xlwings -> comtypes
# anaconda==2021.11 -> comtypes==1.1.10[build='py38haa95532_1002|py39haa95532_1002|py37haa95532_1002']
#
# Package sphinx conflicts for:
# numpydoc -> sphinx[version='>=1.8|>=3.0|>=4.2']
# anaconda==2021.11 -> numpydoc==1.1.0=pyhd3eb1b0_1 -> sphinx[version='>=0.6.6']
# spyder -> numpydoc[version='>=0.6.0'] -> sphinx[version='>=1.8|>=3.0|>=4.2']
# anaconda==2021.11 -> sphinx==4.2.0=pyhd3eb1b0_1
# spyder -> sphinx[version='>=0.6.6']
# jedi -> numpydoc -> sphinx[version='>=1.8|>=3.0|>=4.2']
#
# Package llvmlite conflicts for:
# anaconda==2021.11 -> numba==0.54.1=py39hf11a4ad_0 -> llvmlite[version='>=0.37.0,<0.38.0a0']
# anaconda==2021.11 -> llvmlite==0.37.0[build='py38h23ce68f_1|py37h23ce68f_1|py39h23ce68f_1']
# numba -> llvmlite[version='0.20.*|0.21.*|0.22.*|0.23.*|0.24.*|>=0.25.0,<0.26.0a0|>=0.26.0,<0.27.0a0|>=0.27.0,<0.28.0a0|>=0.28.0,<0.29.0a0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.31.0|>=0.32.0,<0.33.0a0|>=0.32.0|>=0.32.1,<0.33.0a0|>=0.32.1|>=0.33.0,<0.34.0a0|>=0.33.0|>=0.34.0,<0.35|>=0.35.0,<0.36.0a0|>=0.36.0,<0.37.0a0|>=0.37.0,<0.38.0a0|>=0.38.0,<0.39.0a0|>=0.39.*,<0.40']
#
# Package locket conflicts for:
# anaconda==2021.11 -> locket==0.2.1[build='py37haa95532_1|py39haa95532_1|py38haa95532_1']
# dask -> distributed=2022.7.0 -> locket[version='>=1.0.0']
# anaconda==2021.11 -> partd==1.2.0=pyhd3eb1b0_0 -> locket
# distributed -> locket[version='>=1.0.0']
# dask-core -> partd[version='>=0.3.10'] -> locket
# partd -> locket
#
# Package greenlet conflicts for:
# gevent -> greenlet[version='>=0.4.10|>=0.4.13|>=0.4.14|>=0.4.17|>=0.4.17,<2.0|>=1.1.0,<2.0']
# anaconda==2021.11 -> gevent==21.8.0=py39h2bbff1b_1 -> greenlet[version='!=0.4.17|>=1.1.0,<2.0']
# sqlalchemy -> greenlet!=0.4.17
# anaconda==2021.11 -> greenlet==1.1.1[build='py37hd77b12b_0|py39hd77b12b_0|py38hd77b12b_0']
#
# Package isort conflicts for:
# anaconda==2021.11 -> isort==5.9.3=pyhd3eb1b0_0
# pylint -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# spyder -> pylint[version='>=2.5.0,<3.0'] -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# python-lsp-server -> pylint[version='>=2.5.0'] -> isort[version='>=4.2.5,<5|>=4.2.5,<6']
# anaconda==2021.11 -> pylint==2.9.6=py39haa95532_1 -> isort[version='>=4.2.5,<6']
#
# Package lz4 conflicts for:
# scikit-image -> dask[version='>=0.5'] -> lz4
# dask -> lz4
#
# Package ruamel.yaml.clib conflicts for:
# anaconda-project -> ruamel_yaml -> ruamel.yaml.clib[version='>=0.2.6']
# anaconda-client -> ruamel_yaml[version='>=0.11.14'] -> ruamel.yaml.clib[version='>=0.2.6']
# ruamel_yaml -> ruamel.yaml.clib[version='>=0.2.6']
#
# Package pyerfa conflicts for:
# anaconda==2021.11 -> pyerfa==2.0.0[build='py38h2bbff1b_0|py37h2bbff1b_0|py39h2bbff1b_0']
# astropy -> pyerfa[version='>=1.7.3|>=2.0']
# anaconda==2021.11 -> astropy==4.3.1=py39hc7d831d_0 -> pyerfa[version='>=1.7.3']
#
# Package glib conflicts for:
# pyqt -> qt-main=5.15 -> glib[version='>=2.69.1,<3.0a0']
# qt -> qt-main[version='>=5.15,<6'] -> glib[version='>=2.69.1,<3.0a0']
#
# Package backports.shutil_get_terminal_size conflicts for:
# ipykernel -> ipython[version='>=5.0'] -> backports.shutil_get_terminal_size
# get_terminal_size -> backports.shutil_get_terminal_size
# jupyter_console -> ipython -> backports.shutil_get_terminal_size
# anaconda==2021.11 -> get_terminal_size==1.0.0=h38e98db_0 -> backports.shutil_get_terminal_size
# ipywidgets -> ipython[version='>=4.0.0'] -> backports.shutil_get_terminal_size
# anaconda==2021.11 -> backports.shutil_get_terminal_size==1.0.0=pyhd3eb1b0_3
# ipython -> backports.shutil_get_terminal_size
# jupyterlab -> ipython -> backports.shutil_get_terminal_size
#
# Package itsdangerous conflicts for:
# flask -> itsdangerous[version='>=0.21|>=0.24|>=2.0']
# anaconda==2021.11 -> itsdangerous==2.0.1=pyhd3eb1b0_0
# anaconda==2021.11 -> flask==1.1.2=pyhd3eb1b0_0 -> itsdangerous[version='>=0.24']
#
# Package brotlipy conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
# urllib3 -> brotlipy[version='>=0.6.0']
# distributed -> urllib3 -> brotlipy[version='>=0.6.0']
# anaconda==2021.11 -> urllib3==1.26.7=pyhd3eb1b0_0 -> brotlipy[version='>=0.6.0']
# anaconda==2021.11 -> brotlipy==0.7.0[build='py38h2bbff1b_1003|py39h2bbff1b_1003|py37h2bbff1b_1003']
# anaconda-client -> urllib3[version='>=1.26.4'] -> brotlipy[version='>=0.6.0']
#
# Package python-lsp-server conflicts for:
# python-lsp-black -> python-lsp-server[version='>=1.4.0']
# anaconda==2021.11 -> python-lsp-server==1.2.4=pyhd3eb1b0_0
# pyls-spyder -> python-lsp-server[version='>=1.0.1']
# spyder -> pyls-spyder[version='>=0.4.0'] -> python-lsp-server[version='>=1.0.1|>=1.4.0']
# spyder -> python-lsp-server[version='>=1.2.2,<1.3.0|>=1.3.2,<1.4.0|>=1.5.0,<1.6.0']
# anaconda==2021.11 -> pyls-spyder==0.4.0=pyhd3eb1b0_0 -> python-lsp-server[version='>=1.0.1|>=1.2.2,<1.3.0']
#
# Package distributed conflicts for:
# scikit-image -> dask[version='>=0.5'] -> distributed[version='2021.10.0.*|2022.2.1.*|2022.5.0.*|2022.7.0.*|2021.9.1.*|2021.8.1.*|2021.8.0.*|2021.7.2.*|2021.7.0.*|2021.6.2.*|2021.6.1.*|2021.6.0.*|2021.5.1.*|2021.5.0.*|2021.4.1.*|>=2021.4.0|>=2021.3.1|>=2021.3.0|>=2021.2.0|>=2021.1.1|>=2021.1.0|>=2020.12.0|>=2.30.0|>=2.29.0|>=2.27.0|>=2.26.0|>=2.25.0|>=2.24.0|>=2.23.0|>=2.22.0|>=2.20.0|>=2.19.0|>=2.18.0|>=2.17.0|>=2.16.0|>=2.15.0|>=2.14.0|>=2.13.0|>=2.12.0|>=2.11.0|>=2.10.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=2|>=1.28.0|>=1.27.0|>=1.26.1|>=1.26.0|>=1.25.3|>=1.25.0|>=1.24.2|>=1.23.3|>=1.23.2|>=1.23.1|>=1.23.0|>=1.22.0|>=1.21.0|>=1.21.1|>=1.20.0|>=1.19.0|>=1.16.0']
# dask -> distributed[version='2021.10.0.*|2022.2.1.*|2022.5.0.*|2022.7.0.*|2021.9.1.*|2021.8.1.*|2021.8.0.*|2021.7.2.*|2021.7.0.*|2021.6.2.*|2021.6.1.*|2021.6.0.*|2021.5.1.*|2021.5.0.*|2021.4.1.*|>=2021.4.0|>=2021.3.1|>=2021.3.0|>=2021.2.0|>=2021.1.1|>=2021.1.0|>=2020.12.0|>=2.30.0|>=2.29.0|>=2.27.0|>=2.26.0|>=2.25.0|>=2.24.0|>=2.23.0|>=2.22.0|>=2.20.0|>=2.19.0|>=2.18.0|>=2.17.0|>=2.16.0|>=2.15.0|>=2.14.0|>=2.13.0|>=2.12.0|>=2.11.0|>=2.10.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=2|>=1.28.0|>=1.27.0|>=1.26.1|>=1.26.0|>=1.25.3|>=1.25.0|>=1.24.2|>=1.23.3|>=1.23.2|>=1.23.1|>=1.23.0|>=1.22.0|>=1.21.0|>=1.21.1|>=1.20.0|>=1.19.0|>=1.16.0']
# anaconda==2021.11 -> dask==2021.10.0=pyhd3eb1b0_0 -> distributed=2021.10.0
# anaconda==2021.11 -> distributed==2021.10.0[build='py37haa95532_0|py39haa95532_0|py38haa95532_0']
#
# Package spyder-kernels conflicts for:
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.10.1,<1.11.0|>=1.10.2,<1.11.0|>=2.0.1,<2.1.0|>=2.0.3,<2.1.0|>=2.0.4,<2.1.0|>=2.1.1,<2.2.0|>=2.2.1,<2.3.0|>=2.3.3,<2.4.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0']
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> spyder-kernels[version='>=2.1.1,<2.2.0']
# anaconda==2021.11 -> spyder-kernels==2.1.3[build='py37haa95532_0|py39haa95532_0|py38haa95532_0']
#
# Package cookiecutter conflicts for:
# spyder -> cookiecutter[version='>=1.6.0']
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> cookiecutter[version='>=1.6.0']
# anaconda==2021.11 -> cookiecutter==1.7.2=pyhd3eb1b0_0
#
# Package imageio conflicts for:
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0|>=2.4.1']
# anaconda==2021.11 -> imageio==2.9.0=pyhd3eb1b0_0
# anaconda==2021.11 -> scikit-image==0.18.3=py39hf11a4ad_0 -> imageio[version='>=2.3.0']
#
# Package jaraco.itertools conflicts for:
# importlib_metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# zipp -> jaraco.itertools
#
# Package giflib conflicts for:
# imagecodecs -> giflib[version='>=5.2.1,<5.3.0a0']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> giflib[version='>=5.2.1,<5.3.0a0']
# anaconda==2021.11 -> giflib==5.2.1=h62dcd97_0
# anaconda==2021.11 -> imagecodecs==2021.8.26=py39ha1f97ea_0 -> giflib[version='>=5.2.1,<5.3.0a0']
#
# Package python-lsp-black conflicts for:
# spyder -> python-lsp-black[version='>=1.0.0|>=1.2.0']
# anaconda==2021.11 -> python-lsp-black==1.0.0=pyhd3eb1b0_0
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> python-lsp-black[version='>=1.0.0']
#
# Package jdcal conflicts for:
# openpyxl -> jdcal
# anaconda==2021.11 -> jdcal==1.4.1=pyhd3eb1b0_0
#
# Package pytest-cov conflicts for:
# astropy -> pytest-astropy -> pytest-cov[version='>=2.0|>=2.3.1']
# yellowbrick -> pytest-cov[version='>=2.5.1']
#
# Package cython conflicts for:
# anaconda==2021.11 -> cython==0.29.24[build='py39h604cdb4_0|py37h604cdb4_0|py38h604cdb4_0']
# nltk -> gensim -> cython[version='0.29.23|0.29.28|>=0.29.23']
#
# Package pathtools conflicts for:
# watchdog -> pathtools[version='>=0.1.1']
# spyder -> watchdog[version='>=0.10.3'] -> pathtools[version='>=0.1.1']
#
# Package threadpoolctl conflicts for:
# nltk -> scikit-learn -> threadpoolctl[version='>=2.0.0']
# scikit-learn -> threadpoolctl[version='>=2.0.0']
# yellowbrick -> scikit-learn[version='>=1.0.0'] -> threadpoolctl[version='>=2.0.0']
# scikit-learn-intelex -> scikit-learn[version='<1.1'] -> threadpoolctl[version='>=2.0.0']
# anaconda==2021.11 -> threadpoolctl==2.2.0=pyh0d69192_0
# anaconda==2021.11 -> scikit-learn==0.24.2=py39hf11a4ad_1 -> threadpoolctl[version='>=2.0.0']
#
# Package zict conflicts for:
# distributed -> zict[version='>=0.1.2|>=0.1.3']
# anaconda==2021.11 -> zict==2.0.0=pyhd3eb1b0_0
# dask -> distributed=2022.7.0 -> zict[version='>=0.1.2|>=0.1.3']
# anaconda==2021.11 -> distributed==2021.10.0=py39haa95532_0 -> zict[version='>=0.1.3']
#
# Package intervaltree conflicts for:
# spyder -> intervaltree[version='>=3.0.2']
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> intervaltree[version='>=3.0.2']
# anaconda==2021.11 -> intervaltree==3.1.0=pyhd3eb1b0_0
#
# Package heapdict conflicts for:
# zict -> heapdict
# anaconda==2021.11 -> heapdict==1.0.1=pyhd3eb1b0_0
# anaconda==2021.11 -> zict==2.0.0=pyhd3eb1b0_0 -> heapdict
# distributed -> zict[version='>=0.1.3'] -> heapdict
#
# Package conda-pack conflicts for:
# anaconda==2021.11 -> anaconda-project==0.10.1=pyhd3eb1b0_0 -> conda-pack
# anaconda-project -> conda-pack
#
# Package werkzeug conflicts for:
# anaconda==2021.11 -> werkzeug==2.0.2=pyhd3eb1b0_0
# flask -> werkzeug[version='>=0.14|>=0.15|>=2.0|>=0.7,<1.0.0']
# anaconda==2021.11 -> flask==1.1.2=pyhd3eb1b0_0 -> werkzeug[version='>=0.15']
#
# Package twisted conflicts for:
# prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
# jupyter_server -> prometheus_client -> twisted
# nbclassic -> prometheus_client -> twisted
#
# Package immutables conflicts for:
# distributed -> contextvars -> immutables[version='>=0.9']
# sniffio -> contextvars[version='>=2.1'] -> immutables[version='>=0.9']
#
# Package curl conflicts for:
# pycurl -> curl[version='7.55.*|>=7.55.1,<8.0a0']
# anaconda==2021.11 -> curl==7.78.0=h86230a5_0
#
# Package imagecodecs conflicts for:
# anaconda==2021.11 -> tifffile==2021.7.2=pyhd3eb1b0_2 -> imagecodecs[version='>=2021.4.28']
# scikit-image -> tifffile[version='>=2019.7.26'] -> imagecodecs[version='>=2021.3.31|>=2021.4.28']
# anaconda==2021.11 -> imagecodecs==2021.8.26[build='py38ha1f97ea_0|py37ha1f97ea_0|py39ha1f97ea_0']
# tifffile -> imagecodecs[version='>=2021.3.31|>=2021.4.28']
#
# Package libwebp-base conflicts for:
# pillow -> libwebp[version='>=0.3.0'] -> libwebp-base=1.2.4
# libwebp -> libwebp-base=1.2.4
#
# Package pyls-spyder conflicts for:
# spyder -> pyls-spyder[version='>=0.1.1|>=0.3.0|>=0.3.2|>=0.3.2,<0.4.0|>=0.4.0']
# anaconda==2021.11 -> spyder==5.1.5=py39haa95532_1 -> pyls-spyder[version='>=0.4.0']
# anaconda==2021.11 -> pyls-spyder==0.4.0=pyhd3eb1b0_0
#
# Package ply conflicts for:
# pyqt -> sip[version='>=6.6.2,<6.7.0a0'] -> ply
# sip -> ply
# anaconda==2021.11 -> ply==3.11[build='py38_0|py37_0|py39haa95532_0']
#
# Package fastcache conflicts for:
# anaconda==2021.11 -> fastcache==1.1.0[build='py39h196d8e1_0|py37he774522_0|py38he774522_0']
# sympy -> fastcache

# %%
# from yellowbrick.cluster import KElbowVisualizer

# kmeans = KElbowVisualizer( c.KMeans(), k=clusters, timinings=False)
# kmeans.fit( X )
# kmeans.show()
# problema com modulo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\YVES~1.MOU\AppData\Local\Temp/ipykernel_5600/1870095977.py in <module>
# ----> 1 from yellowbrick.cluster import KElbowVisualizer
#       2
#       3 kmeans = KElbowVisualizer( c.KMeans(), k=clusters, timinings=False)
#       4 kmeans.fit( X )
#       5 kmeans.show()
#
# ModuleNotFoundError: No module named 'yellowbrick'

# %% [markdown]
# ## 7.2. Sillhouette Score

# %%
# from yellowbrick.cluster import KElbowVisualizer

# kmeans = KElbowVisualizer( c.KMeans(), k=clusters, metric='silhouette', timinings=False)
# kmeans.fit( X )
# kmeans.show()
# problema com modulo

# %% [markdown]
# # <font color='red'> 8.0. Model Training </font>

# %% [markdown]
# # <font color='red'> 9.0. Cluster Analysis </font>

# %% [markdown]
# # <font color='red'> 10.0. Descrição dos dados </font>
